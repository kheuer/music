# %%
from models import *
from features import *
from data import *
from sklearn.metrics import accuracy_score, classification_report
from sklearn.feature_selection import SelectFromModel
# Out:
# No GPU found. Using CPU.

# %%
(X_train, y_train, ids_train),(X_test, y_test, ids_test),(X_val, y_val, ids_val) = get_train_test_val_features_and_targets(df=df, feature_extractor=compute_spectral_features, splits=10, train_size=0.6, test_size=0.2)

# %%
X_train_reshaped = X_train.reshape(X_train.shape[0], X_train.shape[1]*X_train.shape[2])
X_test_reshaped = X_test.reshape(X_test.shape[0], X_test.shape[1]*X_test.shape[2])
X_val_reshaped = X_val.reshape(X_val.shape[0], X_val.shape[1]*X_val.shape[2])

# %%
svm = create_svm()
svm.fit(X_train_reshaped, y_train)
y_pred_svm = svm.predict(X_test_reshaped)
print("Train Accuracy:", svm.score(X_train_reshaped, y_train))
print("Validation Accuracy:", svm.score(X_val_reshaped, y_val))
print("Test Accuracy :", svm.score(X_test_reshaped, y_test))
# Out:
# Train Accuracy: 0.4087119633180492
# Validation Accuracy: 0.39075
# Test Accuracy : 0.38955597248280177

# %%
X_train_reshaped_norm=norm(X_train_reshaped, compute_spectral_features)
X_test_reshaped_norm=norm(X_test_reshaped, compute_spectral_features)
X_val_reshaped_norm=norm(X_val_reshaped, compute_spectral_features)

# %%
svm = create_svm()
svm.fit(X_train_reshaped_norm, y_train)
y_pred_svm = svm.predict(X_test_reshaped_norm)
print("Train Accuracy:", svm.score(X_train_reshaped_norm, y_train))
print("Validation Accuracy:", svm.score(X_val_reshaped_norm, y_val))
print("Test Accuracy :", svm.score(X_test_reshaped_norm, y_test))
