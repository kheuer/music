# %%
from models import *
from features import *
from data import *
# Out:
# No GPU found. Using CPU.

# %%
(X_train, y_train, ids_train),(X_test, y_test, ids_test),(X_val, y_val, ids_val) = get_train_test_val_features_and_targets(df=df, feature_extractor=compute_spectral_features, splits=10, train_size=0.6, test_size=0.2)

# %%
X_train_reshaped = X_train.reshape(X_train.shape[0], X_train.shape[1]*X_train.shape[2])
X_test_reshaped = X_test.reshape(X_test.shape[0], X_test.shape[1]*X_test.shape[2])
X_val_reshaped = X_val.reshape(X_val.shape[0], X_val.shape[1]*X_val.shape[2])
X_train_reshaped_norm = norm(X_train_reshaped, feature_extractor=compute_spectral_features)
X_test_reshaped_norm = norm(X_test_reshaped, feature_extractor=compute_spectral_features)
X_val_reshaped_norm = norm(X_val_reshaped, feature_extractor=compute_spectral_features)

# %%
model = create_simple_feedforward_model(X_train_reshaped_norm, learning_rate=0.001)
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 77)]              0
#
#  dense_7 (Dense)             (None, 1024)              79872
#
#  dropout_4 (Dropout)         (None, 1024)              0
#
#  dense_8 (Dense)             (None, 1024)              1049600
#
#  dropout_5 (Dropout)         (None, 1024)              0
#
#  dense_9 (Dense)             (None, 512)               524800
#
#  dense_10 (Dense)            (None, 512)               262656
#
#  dropout_6 (Dropout)         (None, 512)               0
#
#  dense_11 (Dense)            (None, 256)               131328
#
#  dropout_7 (Dropout)         (None, 256)               0
#
#  dense_12 (Dense)            (None, 128)               32896
#
#  dense_13 (Dense)            (None, 8)                 1032
#
# =================================================================
# Total params: 2,082,184
# Trainable params: 2,082,184
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 77)]              0
#
#  dense_7 (Dense)             (None, 1024)              79872
#
#  dropout_4 (Dropout)         (None, 1024)              0
#
#  dense_8 (Dense)             (None, 1024)              1049600
#
#  dropout_5 (Dropout)         (None, 1024)              0
#
#  dense_9 (Dense)             (None, 512)               524800
#
#  dense_10 (Dense)            (None, 512)               262656
#
#  dropout_6 (Dropout)         (None, 512)               0
#
#  dense_11 (Dense)            (None, 256)               131328
#
#  dropout_7 (Dropout)         (None, 256)               0
#
#  dense_12 (Dense)            (None, 128)               32896
#
#  dense_13 (Dense)            (None, 8)                 1032
#
# =================================================================
# Total params: 2,082,184
# Trainable params: 2,082,184
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(
    X_train_reshaped_norm,        # Features
    y_train,                 # Integer labels
    validation_data=(X_val_reshaped_norm, y_val),
    epochs=50,
    batch_size=32,
    verbose=1
)
# Out:
# Epoch 1/50
# 1500/1500 [==============================] - 30s 19ms/step - loss: 1.7878 - accuracy: 0.3450 - val_loss: 1.6448 - val_accuracy: 0.4182
# Epoch 2/50
# 1500/1500 [==============================] - 28s 19ms/step - loss: 1.6787 - accuracy: 0.4015 - val_loss: 1.6500 - val_accuracy: 0.4173
# Epoch 3/50
# 1500/1500 [==============================] - 29s 19ms/step - loss: 1.6402 - accuracy: 0.4168 - val_loss: 1.6065 - val_accuracy: 0.4330
# Epoch 4/50
# 1500/1500 [==============================] - 28s 19ms/step - loss: 1.6151 - accuracy: 0.4283 - val_loss: 1.5798 - val_accuracy: 0.4407
# Epoch 5/50
# 1500/1500 [==============================] - 29s 19ms/step - loss: 1.5899 - accuracy: 0.4336 - val_loss: 1.6076 - val_accuracy: 0.4339
# Epoch 6/50
# 1500/1500 [==============================] - 28s 19ms/step - loss: 1.5825 - accuracy: 0.4402 - val_loss: 1.6040 - val_accuracy: 0.4291
# Epoch 7/50
# 1500/1500 [==============================] - 28s 19ms/step - loss: 1.5700 - accuracy: 0.4454 - val_loss: 1.5958 - val_accuracy: 0.4314
# Epoch 8/50
# 1500/1500 [==============================] - 27s 18ms/step - loss: 1.5631 - accuracy: 0.4493 - val_loss: 1.5812 - val_accuracy: 0.4412
# Epoch 9/50
# 1500/1500 [==============================] - 27s 18ms/step - loss: 1.5517 - accuracy: 0.4535 - val_loss: 1.5734 - val_accuracy: 0.4406
# Epoch 10/50
# 1500/1500 [==============================] - 27s 18ms/step - loss: 1.5428 - accuracy: 0.4564 - val_loss: 1.5755 - val_accuracy: 0.4379
# Epoch 11/50
# 1500/1500 [==============================] - 27s 18ms/step - loss: 1.5343 - accuracy: 0.4635 - val_loss: 1.5587 - val_accuracy: 0.4486
# Epoch 12/50
# 1500/1500 [==============================] - 27s 18ms/step - loss: 1.5270 - accuracy: 0.4657 - val_loss: 1.5647 - val_accuracy: 0.4509
# Epoch 13/50
# 1500/1500 [==============================] - 27s 18ms/step - loss: 1.5219 - accuracy: 0.4672 - val_loss: 1.5719 - val_accuracy: 0.4377
# Epoch 14/50
# 1500/1500 [==============================] - 27s 18ms/step - loss: 1.5177 - accuracy: 0.4683 - val_loss: 1.5455 - val_accuracy: 0.4541
# Epoch 15/50
# 1500/1500 [==============================] - 27s 18ms/step - loss: 1.5099 - accuracy: 0.4696 - val_loss: 1.5630 - val_accuracy: 0.4454
# Epoch 16/50
# 1500/1500 [==============================] - 27s 18ms/step - loss: 1.5126 - accuracy: 0.4707 - val_loss: 1.5536 - val_accuracy: 0.4507
# Epoch 17/50
# 1500/1500 [==============================] - 27s 18ms/step - loss: 1.5004 - accuracy: 0.4739 - val_loss: 1.5358 - val_accuracy: 0.4526
# Epoch 18/50
# 1500/1500 [==============================] - 27s 18ms/step - loss: 1.4994 - accuracy: 0.4759 - val_loss: 1.5546 - val_accuracy: 0.4584
# Epoch 19/50
# 1500/1500 [==============================] - 27s 18ms/step - loss: 1.4979 - accuracy: 0.4805 - val_loss: 1.5544 - val_accuracy: 0.4507
# Epoch 20/50
# 1500/1500 [==============================] - 27s 18ms/step - loss: 1.4863 - accuracy: 0.4820 - val_loss: 1.5400 - val_accuracy: 0.4546
# Epoch 21/50
# 1500/1500 [==============================] - 27s 18ms/step - loss: 1.4805 - accuracy: 0.4845 - val_loss: 1.5496 - val_accuracy: 0.4510
# Epoch 22/50
# 1500/1500 [==============================] - 27s 18ms/step - loss: 1.4817 - accuracy: 0.4834 - val_loss: 1.5612 - val_accuracy: 0.4536
# Epoch 23/50
# 1500/1500 [==============================] - 27s 18ms/step - loss: 1.4723 - accuracy: 0.4874 - val_loss: 1.5631 - val_accuracy: 0.4473
# Epoch 24/50
# 1500/1500 [==============================] - 27s 18ms/step - loss: 1.4671 - accuracy: 0.4883 - val_loss: 1.5711 - val_accuracy: 0.4546
# Epoch 25/50
# 1500/1500 [==============================] - 28s 18ms/step - loss: 1.4683 - accuracy: 0.4892 - val_loss: 1.5668 - val_accuracy: 0.4512
# Epoch 26/50
# 1500/1500 [==============================] - 27s 18ms/step - loss: 1.4617 - accuracy: 0.4940 - val_loss: 1.5511 - val_accuracy: 0.4549
# Epoch 27/50
# 1500/1500 [==============================] - 29s 19ms/step - loss: 1.4561 - accuracy: 0.4938 - val_loss: 1.5645 - val_accuracy: 0.4411
# Epoch 28/50
# 1500/1500 [==============================] - 27s 18ms/step - loss: 1.4605 - accuracy: 0.4932 - val_loss: 1.5742 - val_accuracy: 0.4361
# Epoch 29/50
# 1500/1500 [==============================] - 27s 18ms/step - loss: 1.4582 - accuracy: 0.4944 - val_loss: 1.5590 - val_accuracy: 0.4456
# Epoch 30/50
# 1500/1500 [==============================] - 27s 18ms/step - loss: 1.4469 - accuracy: 0.4973 - val_loss: 1.5460 - val_accuracy: 0.4574
# Epoch 31/50
# 1500/1500 [==============================] - 27s 18ms/step - loss: 1.4540 - accuracy: 0.4982 - val_loss: 1.5541 - val_accuracy: 0.4616
# Epoch 32/50
# 1500/1500 [==============================] - 27s 18ms/step - loss: 1.4411 - accuracy: 0.5022 - val_loss: 1.5552 - val_accuracy: 0.4559
# Epoch 33/50
# 1500/1500 [==============================] - 28s 19ms/step - loss: 1.4396 - accuracy: 0.5018 - val_loss: 1.5494 - val_accuracy: 0.4606
# Epoch 34/50
# 1500/1500 [==============================] - 28s 19ms/step - loss: 1.4454 - accuracy: 0.5009 - val_loss: 1.5493 - val_accuracy: 0.4643
# Epoch 35/50
# 1500/1500 [==============================] - 29s 19ms/step - loss: 1.4288 - accuracy: 0.5075 - val_loss: 1.5459 - val_accuracy: 0.4646
# Epoch 36/50
# 1500/1500 [==============================] - 29s 19ms/step - loss: 1.4328 - accuracy: 0.5051 - val_loss: 1.5652 - val_accuracy: 0.4516
# Epoch 37/50
# 1500/1500 [==============================] - 28s 19ms/step - loss: 1.4297 - accuracy: 0.5083 - val_loss: 1.5527 - val_accuracy: 0.4556
# Epoch 38/50
# 1500/1500 [==============================] - 29s 19ms/step - loss: 1.4272 - accuracy: 0.5061 - val_loss: 1.5462 - val_accuracy: 0.4628
# Epoch 39/50
# 1500/1500 [==============================] - 29s 19ms/step - loss: 1.4292 - accuracy: 0.5082 - val_loss: 1.5414 - val_accuracy: 0.4567
# Epoch 40/50
# 1500/1500 [==============================] - 28s 19ms/step - loss: 1.4213 - accuracy: 0.5107 - val_loss: 1.5619 - val_accuracy: 0.4521
# Epoch 41/50
# 1500/1500 [==============================] - 28s 19ms/step - loss: 1.4242 - accuracy: 0.5117 - val_loss: 1.5589 - val_accuracy: 0.4486
# Epoch 42/50
# 1500/1500 [==============================] - 28s 19ms/step - loss: 1.4178 - accuracy: 0.5115 - val_loss: 1.5743 - val_accuracy: 0.4436
# Epoch 43/50
# 1500/1500 [==============================] - 28s 19ms/step - loss: 1.4138 - accuracy: 0.5132 - val_loss: 1.5455 - val_accuracy: 0.4546
# Epoch 44/50
# 1500/1500 [==============================] - 28s 18ms/step - loss: 1.4101 - accuracy: 0.5159 - val_loss: 1.5538 - val_accuracy: 0.4554
# Epoch 45/50
# 1500/1500 [==============================] - 27s 18ms/step - loss: 1.4138 - accuracy: 0.5125 - val_loss: 1.5382 - val_accuracy: 0.4591
# Epoch 46/50
# 1500/1500 [==============================] - 28s 19ms/step - loss: 1.4088 - accuracy: 0.5164 - val_loss: 1.5695 - val_accuracy: 0.4487
# Epoch 47/50
# 1500/1500 [==============================] - 28s 19ms/step - loss: 1.4077 - accuracy: 0.5183 - val_loss: 1.5469 - val_accuracy: 0.4577
# Epoch 48/50
# 1500/1500 [==============================] - 28s 19ms/step - loss: 1.4063 - accuracy: 0.5166 - val_loss: 1.5553 - val_accuracy: 0.4546
# Epoch 49/50
# 1500/1500 [==============================] - 28s 19ms/step - loss: 1.4020 - accuracy: 0.5208 - val_loss: 1.5641 - val_accuracy: 0.4558
# Epoch 50/50
# 1500/1500 [==============================] - 28s 19ms/step - loss: 1.4031 - accuracy: 0.5212 - val_loss: 1.5535 - val_accuracy: 0.4516

# %%
test_loss, test_acc = model.evaluate(X_test_reshaped_norm, y_test, verbose=0)

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# Test Loss: 1.5516
# Test Accuracy: 0.4488

# %%
y_pred_prob = model.predict(X_test_reshaped_norm)
y_pred = np.argmax(y_pred_prob, axis=1)

print(y_pred[:10])
# Out:
# 500/500 [==============================] - 2s 3ms/step
# [5 6 3 4 1 4 4 7 2 0]
